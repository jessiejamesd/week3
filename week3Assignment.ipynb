# %% [markdown]
# # **Assignment on Python for Data Science**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **1. Read the dataset to python environment.**

# %% [markdown]
# ##### Reading the file iris.xls file and its content using read_excel().150 observations found!

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
df=pd.read_excel('/content/gdrive/MyDrive/ICTAK/iris.xls')
df=df.rename(columns={"SL": "Sepal Length", "SW": "Sepal Width", "PL":"Petal Length", "PW":"Petal Width", "classification":"Classification"})
df
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width  Classification
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **2. Display the columns in the dataset.**

# %% [markdown]
# ##### The following are the columns found in the dataset

# %%
df.columns
# Out:
# Index(['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width',
#        'Classification'],
#       dtype='object')

# %% [markdown]
# **3. Calculate the mean of each column of the dataset.**

# %% [markdown]
# ##### The mean for each column is calculated using mean()

# %%
df.mean(axis=0, skipna = True)
# Out:
# Sepal Length    5.843333
# Sepal Width     3.054000
# Petal Length    3.758667
# Petal Width     1.198667
# dtype: float64

# %% [markdown]
# **4. Check for the null values present in the dataset.**

# %% [markdown]
# ##### No null records found!

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Sepal Length, Sepal Width, Petal Length, Petal Width, Classification]
# Index: []

# %% [markdown]
# **5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.**

# %% [markdown]
# 5.1. Scatter Plot based on Classification with Sepal Length on X-axis and Sepal Width on Y-axis

# %%
#versicolor=df.loc[df['Classification'] == 'Iris-versicolor']
group_list = list(df.groupby('Classification').groups.keys())
group_list
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %% [markdown]
# ##### Now we got 3 different Classifications.

# %%
setosa=df.loc[df['Classification'] == group_list[0]]
setosa.plot.scatter(x='Sepal Length', y='Sepal Width', color='red', marker='*', s=100)
plt.title("Iris Setosa",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Setosa')

# %%
virginica=df.loc[df['Classification'] == group_list[2]]
virginica.plot.scatter(x='Sepal Length', y='Sepal Width', color='blue', marker='^', s=100)
plt.title("Iris Virginica",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Virginica')

# %%
versicolor=df.loc[df['Classification'] == group_list[1]]
versicolor.plot.scatter(x='Sepal Length', y='Sepal Width', color='green', marker='>', s=100)
plt.title("Iris Versicolor",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Versicolor')

# %% [markdown]
# 5.2. Box Plot

# %% [markdown]
# ##### Box Plotting for the flower classification Iris Setosa

# %%
setosa.plot.box()
plt.title("Iris Setosa",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Setosa')

# %% [markdown]
# ##### Box Plotting for the flower classification Iris Virginica

# %%
virginica.plot.box()
plt.title("Iris Virginica",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Virginica')

# %% [markdown]
# ##### Box Plotting for the flower classification Iris Versicolor

# %%
versicolor.plot.box()
plt.title("Iris Versicolor",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Versicolor')

# %% [markdown]
# 5.3. Histogram

# %% [markdown]
# ##### Plotting Histogram for the flower Classification Iris Setosa with Sepal Length, Sepal Width, Petal Length and Petal Width along the x-axis and their frequencies along the y-axis

# %%
setosa.plot.hist(rwidth=0.9)
plt.title("Iris Setosa",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Setosa')

# %% [markdown]
# ##### Plotting Histogram for the flower Classification Iris Virginica with Sepal Length, Sepal Width, Petal Length and Petal Width along the x-axis and their frequencies along the y-axis

# %%
virginica.plot.hist(rwidth=0.9)
plt.title("Iris Virginica",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Virginica')

# %% [markdown]
# ##### Plotting Histogram for the flower Classification Iris Versicolor with Sepal Length, Sepal Width, Petal Length and Petal Width along the x-axis and their frequencies along the y-axis

# %%
versicolor.plot.hist(rwidth=0.9)
plt.title("Iris Versicolor",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Iris Versicolor')
